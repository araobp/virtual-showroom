# %% [markdown]
# # Scenarios
#
# Date: 2024/09/07, 2024/09/09, 2024/09/11

# %%
from IPython.display import Image, display
import glob
import cv2
import matplotlib.pyplot as plt

scenarios = []


YOKOHAMA = 'yokohama'
TAKANAWA = 'takanawa_gateway_station'
HANSAPLATZ = 'hansaplatz'
DRESDENSTATION = 'dresden_station'

# 240-degree panorama pictures
IMG_FILES = "../../VirtualShowroom/Assets/Resources/Panorama/*.jpg"
paths = sorted(glob.glob(IMG_FILES))
paths
# Out:
# ['../../VirtualShowroom/Assets/Resources/Panorama/IMG_0227_level.jpg',
#  '../../VirtualShowroom/Assets/Resources/Panorama/IMG_0230_level.jpg',
#  '../../VirtualShowroom/Assets/Resources/Panorama/IMG_0231_level.jpg',
#  '../../VirtualShowroom/Assets/Resources/Panorama/IMG_0232_level.jpg',
#  '../../VirtualShowroom/Assets/Resources/Panorama/IMG_0236_level.jpg',
#  '../../VirtualShowroom/Assets/Resources/Panorama/IMG_0238_level.jpg',
#  '../../VirtualShowroom/Assets/Resources/Panorama/IMG_0248_level.jpg',
#  '../../VirtualShowroom/Assets/Resources/Panorama/IMG_0249_level.jpg',
#  '../../VirtualShowroom/Assets/Resources/Panorama/IMG_0252_level.jpg',
#  '../../VirtualShowroom/Assets/Resources/Panorama/IMG_0254_level.jpg',
#  '../../VirtualShowroom/Assets/Resources/Panorama/IMG_0256_level.jpg',
#  '../../VirtualShowroom/Assets/Resources/Panorama/PolyHaven_DresdenStation.jpg',
#  '../../VirtualShowroom/Assets/Resources/Panorama/PolyHaven_Hansaplatz.jpg']

# %%
filenames = {}
scenarios = {}
for p in paths:
    name = p.split('/')[-1].split('_')[:2]
    name = '_'.join(name)
    name = name.replace('.jpg', '')  # Remove file extentions (".jpg")
    filenames[name] = p

filenames
# Out:
# {'IMG_0227': '../../VirtualShowroom/Assets/Resources/Panorama/IMG_0227_level.jpg',
#  'IMG_0230': '../../VirtualShowroom/Assets/Resources/Panorama/IMG_0230_level.jpg',
#  'IMG_0231': '../../VirtualShowroom/Assets/Resources/Panorama/IMG_0231_level.jpg',
#  'IMG_0232': '../../VirtualShowroom/Assets/Resources/Panorama/IMG_0232_level.jpg',
#  'IMG_0236': '../../VirtualShowroom/Assets/Resources/Panorama/IMG_0236_level.jpg',
#  'IMG_0238': '../../VirtualShowroom/Assets/Resources/Panorama/IMG_0238_level.jpg',
#  'IMG_0248': '../../VirtualShowroom/Assets/Resources/Panorama/IMG_0248_level.jpg',
#  'IMG_0249': '../../VirtualShowroom/Assets/Resources/Panorama/IMG_0249_level.jpg',
#  'IMG_0252': '../../VirtualShowroom/Assets/Resources/Panorama/IMG_0252_level.jpg',
#  'IMG_0254': '../../VirtualShowroom/Assets/Resources/Panorama/IMG_0254_level.jpg',
#  'IMG_0256': '../../VirtualShowroom/Assets/Resources/Panorama/IMG_0256_level.jpg',
# ...

# %%
def imshow(path):
    img = cv2.imread(path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(img)

# %% [markdown]
# ## IMG_0227

# %%
# IMG_0227
imshow(filenames['IMG_0227'])

# %%
scenarios['IMG_0227'] = ('''
この240度パノラマ写真は横浜の臨港パークから撮影されたものです。右手には横浜ハンマーヘッドが見えます。
''',
YOKOHAMA)

# %% [markdown]
# ## IMG_0230

# %%
# IMG_0230
imshow(filenames['IMG_0230'])

# %%
scenarios['IMG_0230'] = ('''
この240度パノラマ写真は横浜の山下臨港線プロムナードから撮影されたものです。左手にはみなとみらい２１の中心街、赤レンガ倉庫や横浜税関（クイーンの塔）が見えます。
右手には横浜大さん橋が見えます。
''',
YOKOHAMA)

# %% [markdown]
# ## IMG_0231

# %%
# IMG_0231
imshow(filenames['IMG_0231'])

# %%
scenarios['IMG_0231'] = ('''
この240度パノラマ写真は横浜の山下臨港線プロムナードから撮影されたものです。左手にはみなとみらい２１の中心街、赤レンガ倉庫や横浜税関（クイーンの塔）が見えます。
右手には横浜大さん橋が見えます。
''',
YOKOHAMA)

# %% [markdown]
# ## IMG_0232

# %%
# IMG_0232
imshow(filenames['IMG_0232'])

# %%
scenarios['IMG_0232'] = ('''
この240度パノラマ写真は横浜大さん橋から撮影されたものです。中央から左手にかけては、みなとみらい２１の中心街や赤レンガ倉庫が見えます。また、画面中央付近には海上保安庁の巡視船が停泊しています。
''',
YOKOHAMA)

# %% [markdown]
# ## IMG_0236

# %%
# IMG_0236
imshow(filenames['IMG_0236'])

# %%
scenarios['IMG_0236'] = ('''
この240度パノラマ写真は横浜大さん橋から撮影されたものです。左手にはみなとみらい２１の中心街、赤レンガ倉庫や横浜税関（クイーンの塔）、右手には横浜ベイブリッジが見えます。
大さん橋の一番奥には双眼鏡が設置されており、高台から横浜港を一望することが出来ます。
''',
YOKOHAMA)

# %% [markdown]
# ## IMG_0238

# %%
# IMG_0238
imshow(filenames['IMG_0238'])

# %%
scenarios['IMG_0238'] = ('''
この240度パノラマ写真は横浜大さん橋から撮影されたものです。右手にはみなとみらい２１の中心街や赤レンガ倉庫、左手には氷川丸、山下埠頭や横浜ベイブリッジが見えます。
''',
YOKOHAMA)

# %% [markdown]
# ## IMG_0248

# %%
# IMG_0248
imshow(filenames['IMG_0248'])

# %%
scenarios['IMG_0248'] = ('''
この240度パノラマ写真は高輪ゲートウェイ駅構内で撮影されたものです。画面左手には山手線のホーム、画面中央付近には京浜東北線のホームが見えます。
''',
TAKANAWA)

# %% [markdown]
# ## IMG_0249

# %%
# IMG_0249
imshow(filenames['IMG_0249'])

# %%
scenarios['IMG_0249'] = ('''
この240度パノラマ写真は高輪ゲートウェイ駅構内で撮影されたものです。画面左手には山手線のホーム、画面中央付近には京浜東北線のホームが見えます。
''',
TAKANAWA)

# %% [markdown]
# ## IMG_0252

# %%
# IMG_0252
imshow(filenames['IMG_0252'])

# %%
scenarios['IMG_0252'] = ('''
この240度パノラマ写真は高輪ゲートウェイ駅構内で撮影されたものです。画面右手には東京総合車両センターの車両基地が見えます。
''',
TAKANAWA)

# %% [markdown]
# ## IMG_0254

# %%
# IMG_0254
imshow(filenames['IMG_0254'])

# %%
scenarios['IMG_0254'] = ('''
この240度パノラマ写真は高輪ゲートウェイ駅構内で撮影されたものです。画面右手には東京総合車両センターの車両基地が見えます。
''',
TAKANAWA)

# %% [markdown]
# ## IMG_256

# %%
# IMG_0256
imshow(filenames['IMG_0256'])

# %%
scenarios['IMG_0256'] = ('''
この240度パノラマ写真は高輪ゲートウェイ駅構内で撮影されたものです。画面左手の壁には、駅を開発時の工事現場写真や、まだ開発中な駅周辺の完成予想図が飾られています。
''',
TAKANAWA)

# %% [markdown]
# ## PolyHaven_Hansaplatz

# %%
# PolyHaven_Hansaplatz
imshow(filenames['PolyHaven_Hansaplatz'])

# %%
scenarios['PolyHaven_Hansaplatz'] = ('''
この240度パノラマ写真はHamburg(ハンブルク)のHansaplatz(ハンザ広場)で撮影されたものです。ドイツの広場らしい石畳の広場です。。
''',
HANSAPLATZ)

# %% [markdown]
# ## PolyHaven_DresdenStation

# %%
# PolyHaven_DresdenStation
imshow(filenames['PolyHaven_DresdenStation'])

# %%
scenarios['PolyHaven_DresdenStation'] = ('''
この240度パノラマ写真はDresden(ドレスデン)のDresden Central Station(ドレスデン中央駅)で撮影されたものです。ドイツらしい屋根付きの駅です。
''',
DRESDENSTATION)

# %% [markdown]
# ## Save the scenarios to SQLite database

# %%
import sqlite3

with sqlite3.connect('db/scenarios.db') as conn:
    cur = conn.cursor()
    cur.execute('CREATE TABLE IF NOT EXISTS scenarios (image TEXT PRIMARY KEY, scene_id TEXT, scenario TEXT)')
    cur.execute('DELETE FROM scenarios')
    data = list(zip(scenarios.keys(), [e[1] for e in scenarios.values()], [e[0] for e in scenarios.values()]))
    cur.executemany('insert into scenarios(image, scene_id, scenario) values (?,?,?)', data)

# %%
with sqlite3.connect('db/scenarios.db') as conn:
    cur = conn.cursor()
    records = cur.execute('SELECT * FROM scenarios').fetchall()

records
# Out:
# [('IMG_0227',
#   'yokohama',
#   '\nこの240度パノラマ写真は横浜の臨港パークから撮影されたものです。右手には横浜ハンマーヘッドが見えます。\n'),
#  ('IMG_0230',
#   'yokohama',
#   '\nこの240度パノラマ写真は横浜の山下臨港線プロムナードから撮影されたものです。左手にはみなとみらい２１の中心街、赤レンガ倉庫や横浜税関（クイーンの塔）が見えます。\n右手には横浜大さん橋が見えます。\n'),
#  ('IMG_0231',
#   'yokohama',
#   '\nこの240度パノラマ写真は横浜の山下臨港線プロムナードから撮影されたものです。左手にはみなとみらい２１の中心街、赤レンガ倉庫や横浜税関（クイーンの塔）が見えます。\n右手には横浜大さん橋が見えます。\n'),
#  ('IMG_0232',
#   'yokohama',
#   '\nこの240度パノラマ写真は横浜大さん橋から撮影されたものです。中央から左手にかけては、みなとみらい２１の中心街や赤レンガ倉庫が見えます。また、画面中央付近には海上保安庁の巡視船が停泊しています。\n'),
#  ('IMG_0236',
#   'yokohama',
#   '\nこの240度パノラマ写真は横浜大さん橋から撮影されたものです。左手にはみなとみらい２１の中心街、赤レンガ倉庫や横浜税関（クイーンの塔）、右手には横浜ベイブリッジが見えます。\n大さん橋の一番奥には双眼鏡が設置されており、高台から横浜港を一望することが出来ます。\n'),
#  ('IMG_0238',
#   'yokohama',
#   '\nこの240度パノラマ写真は横浜大さん橋から撮影されたものです。右手にはみなとみらい２１の中心街や赤レンガ倉庫、左手には氷川丸、山下埠頭や横浜ベイブリッジが見えます。\n'),
#  ('IMG_0248',
#   'takanawa_gateway_station',
#   '\nこの240度パノラマ写真は高輪ゲートウェイ駅構内で撮影されたものです。画面左手には山手線のホーム、画面中央付近には京浜東北線のホームが見えます。\n'),
#  ('IMG_0249',
# ...
